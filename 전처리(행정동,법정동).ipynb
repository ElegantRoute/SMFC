# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('bubhangchange.xlsx')

# %%
data.head()
# Out:
#         행정동코드    시도명 시군구명   읍면동명       법정동코드    동리명      생성일자  말소일자
# 0  1100000000  서울특별시  NaN    NaN  1100000000  서울특별시  19880423   NaN
# 1  1111000000  서울특별시  종로구    NaN  1111000000    종로구  19880423   NaN
# 2  1111051500  서울특별시  종로구  청운효자동  1111010100    청운동  20081101   NaN
# 3  1111051500  서울특별시  종로구  청운효자동  1111010200    신교동  20081101   NaN
# 4  1111051500  서울특별시  종로구  청운효자동  1111010300    궁정동  20081101   NaN

# %%
data.drop(columns=['말소일자','생성일자'],inplace=True)

# %%
data = data[data['시도명']=='서울특별시']

# %%
data.dropna(inplace=True)

# %%
data.reset_index(inplace=True)

# %%
data.drop(columns='index',inplace=True)

# %%
data.head()
# Out:
#         행정동코드    시도명 시군구명   읍면동명       법정동코드  동리명
# 0  1111051500  서울특별시  종로구  청운효자동  1111010100  청운동
# 1  1111051500  서울특별시  종로구  청운효자동  1111010200  신교동
# 2  1111051500  서울특별시  종로구  청운효자동  1111010300  궁정동
# 3  1111051500  서울특별시  종로구  청운효자동  1111010400  효자동
# 4  1111051500  서울특별시  종로구  청운효자동  1111010500  창성동

# %%
data[data['동리명']=='용산동5가']
# Out:
#           행정동코드    시도명 시군구명  읍면동명       법정동코드    동리명
# 211  1117062500  서울특별시  용산구  한강로동  1117012700  용산동5가

# %%
len(data['읍면동명'].unique())
# Out:
# 423

# %%
data

# %%
addr = []
for x,y,z in zip(data['시도명'],data['시군구명'],data['읍면동명']):
    addr.append(x +" "+ y + " " + z)

# %%
set(addr)
# Out:
# {'서울특별시 강남구 개포1동',
#  '서울특별시 강남구 개포2동',
#  '서울특별시 강남구 개포4동',
#  '서울특별시 강남구 논현1동',
#  '서울특별시 강남구 논현2동',
#  '서울특별시 강남구 대치1동',
#  '서울특별시 강남구 대치2동',
#  '서울특별시 강남구 대치4동',
#  '서울특별시 강남구 도곡1동',
#  '서울특별시 강남구 도곡2동',
#  '서울특별시 강남구 삼성1동',
#  '서울특별시 강남구 삼성2동',
#  '서울특별시 강남구 세곡동',
#  '서울특별시 강남구 수서동',
#  '서울특별시 강남구 신사동',
#  '서울특별시 강남구 압구정동',
#  '서울특별시 강남구 역삼1동',
#  '서울특별시 강남구 역삼2동',
#  '서울특별시 강남구 일원1동',
#  '서울특별시 강남구 일원2동',
#  '서울특별시 강남구 일원본동',
#  '서울특별시 강남구 청담동',
#  '서울특별시 강동구 강일동',
#  '서울특별시 강동구 고덕제1동',
#  '서울특별시 강동구 고덕제2동',
#  '서울특별시 강동구 길동',
#  '서울특별시 강동구 둔촌제1동',
#  '서울특별시 강동구 둔촌제2동',
#  '서울특별시 강동구 명일제1동',
#  '서울특별시 강동구 명일제2동',
#  '서울특별시 강동구 상일동',
#  '서울특별시 강동구 성내제1동',
#  '서울특별시 강동구 성내제2동',
#  '서울특별시 강동구 성내제3동',
#  '서울특별시 강동구 암사제1동',
#  '서울특별시 강동구 암사제2동',
#  '서울특별시 강동구 암사제3동',
#  '서울특별시 강동구 천호제1동',
#  '서울특별시 강동구 천호제2동',
#  '서울특별시 강동구 천호제3동',
#  '서울특별시 강북구 미아동',
#  '서울특별시 강북구 번제1동',
#  '서울특별시 강북구 번제2동',
#  '서울특별시 강북구 번제3동',
#  '서울특별시 강북구 삼각산동',
#  '서울특별시 강북구 삼양동',
#  '서울특별시 강북구 송중동',
# ...

# %%
len(set(addr))
# Out:
# 424

# %%
data['행정동'] = addr

# %%
data.head()
# Out:
#         행정동코드    시도명 시군구명   읍면동명       법정동코드  동리명              행정동
# 0  1111051500  서울특별시  종로구  청운효자동  1111010100  청운동  서울특별시 종로구 청운효자동
# 1  1111051500  서울특별시  종로구  청운효자동  1111010200  신교동  서울특별시 종로구 청운효자동
# 2  1111051500  서울특별시  종로구  청운효자동  1111010300  궁정동  서울특별시 종로구 청운효자동
# 3  1111051500  서울특별시  종로구  청운효자동  1111010400  효자동  서울특별시 종로구 청운효자동
# 4  1111051500  서울특별시  종로구  청운효자동  1111010500  창성동  서울특별시 종로구 청운효자동

# %%
addr1 = []
for x,y,z in zip(data['시도명'],data['시군구명'],data['동리명']):
    addr1.append(x +" "+ y + " " + z)

# %%
data['법정동'] = addr1

# %%
data.head()
# Out:
#         행정동코드    시도명 시군구명   읍면동명       법정동코드  동리명              행정동  \
# 0  1111051500  서울특별시  종로구  청운효자동  1111010100  청운동  서울특별시 종로구 청운효자동
# 1  1111051500  서울특별시  종로구  청운효자동  1111010200  신교동  서울특별시 종로구 청운효자동
# 2  1111051500  서울특별시  종로구  청운효자동  1111010300  궁정동  서울특별시 종로구 청운효자동
# 3  1111051500  서울특별시  종로구  청운효자동  1111010400  효자동  서울특별시 종로구 청운효자동
# 4  1111051500  서울특별시  종로구  청운효자동  1111010500  창성동  서울특별시 종로구 청운효자동
#
#              법정동
# 0  서울특별시 종로구 청운동
# 1  서울특별시 종로구 신교동
# 2  서울특별시 종로구 궁정동
# 3  서울특별시 종로구 효자동
# 4  서울특별시 종로구 창성동

# %%
data = data[['행정동코드','행정동','법정동코드','법정동']]

# %%
data.head()
# Out:
#         행정동코드              행정동       법정동코드            법정동
# 0  1111051500  서울특별시 종로구 청운효자동  1111010100  서울특별시 종로구 청운동
# 1  1111051500  서울특별시 종로구 청운효자동  1111010200  서울특별시 종로구 신교동
# 2  1111051500  서울특별시 종로구 청운효자동  1111010300  서울특별시 종로구 궁정동
# 3  1111051500  서울특별시 종로구 청운효자동  1111010400  서울특별시 종로구 효자동
# 4  1111051500  서울특별시 종로구 청운효자동  1111010500  서울특별시 종로구 창성동

# %%
data.to_csv('hangbub.csv',encoding='cp949')
